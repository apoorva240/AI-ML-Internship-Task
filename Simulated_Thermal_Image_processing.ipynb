# %%
import cv2
import requests
import numpy as np
from io import BytesIO
from google.colab.patches import cv2_imshow

# Function to process simulated thermal images
def process_thermal_image(image_url):
    # Download the image from the web
    response = requests.get(image_url)
    original_image = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_COLOR)

    # Convert the image to grayscale
    grayscale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Apply a color map to simulate a thermal image (e.g., using COLORMAP_JET)
    thermal_image = cv2.applyColorMap(grayscale_image, cv2.COLORMAP_JET)

    # Display the original and processed images using cv2_imshow
    cv2_imshow(original_image)
    cv2_imshow(thermal_image)

# Replace 'https://media.istockphoto.com/id/517188688/photo/mountain-landscape.jpg?s=612x612&w=0&k=20&c=A63koPKaCyIwQWOTFBRWXj_PwCrR4cEoOw2S9Q7yVl8='
# with the actual URL of an image you want to use
image_url = 'https://media.istockphoto.com/id/517188688/photo/mountain-landscape.jpg?s=612x612&w=0&k=20&c=A63koPKaCyIwQWOTFBRWXj_PwCrR4cEoOw2S9Q7yVl8='
process_thermal_image(image_url)
# Out:
# <PIL.Image.Image image mode=RGB size=612x384>
# <PIL.Image.Image image mode=RGB size=612x384>

# %%
import cv2
import requests
import numpy as np
from io import BytesIO
from google.colab.patches import cv2_imshow

def process_thermal_image(image_url):
    # Download the image from the web
    response = requests.get(image_url)
    original_image = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_COLOR)

    # Convert the image to grayscale
    grayscale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Apply a color map to simulate a thermal image (e.g., using COLORMAP_JET)
    thermal_image = cv2.applyColorMap(grayscale_image, cv2.COLORMAP_JET)

    # Apply Gaussian blur to the grayscale image
    blurred_image = cv2.GaussianBlur(grayscale_image, (5, 5), 0)

    # Threshold the blurred image to create a binary image
    _, binary_image = cv2.threshold(blurred_image, 127, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Draw contours on the original image
    image_with_contours = original_image.copy()
    cv2.drawContours(image_with_contours, contours, -1, (0, 255, 0), 2)

    # Display the original, grayscale, thermal, blurred, binary, and contours images
    cv2_imshow(original_image)
    cv2_imshow(grayscale_image)
    cv2_imshow(thermal_image)
    cv2_imshow(blurred_image)
    cv2_imshow(binary_image)
    cv2_imshow(image_with_contours)


image_url = 'https://media.istockphoto.com/id/517188688/photo/mountain-landscape.jpg?s=612x612&w=0&k=20&c=A63koPKaCyIwQWOTFBRWXj_PwCrR4cEoOw2S9Q7yVl8='
process_thermal_image(image_url)
# Out:
# <PIL.Image.Image image mode=RGB size=612x384>
# <PIL.Image.Image image mode=L size=612x384>
# <PIL.Image.Image image mode=RGB size=612x384>
# <PIL.Image.Image image mode=L size=612x384>
# <PIL.Image.Image image mode=L size=612x384>
# <PIL.Image.Image image mode=RGB size=612x384>
